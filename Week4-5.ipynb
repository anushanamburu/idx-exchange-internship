# %% [markdown]
# # Week 4-5 Deliverable

# %%
import pandas as pd

# %% [markdown]
# ### Read Datasets

# %%
sold = pd.read_csv("soldFINAL.csv")
list = pd.read_csv("listFINAL.csv")
# Out:
# /var/folders/y8/n1dk_n9n2fsf3cpk4z474lmc0000gn/T/ipykernel_3882/1751507686.py:1: DtypeWarning: Columns (0,1,9,53,65,66,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv("soldFINAL.csv")
# /var/folders/y8/n1dk_n9n2fsf3cpk4z474lmc0000gn/T/ipykernel_3882/1751507686.py:2: DtypeWarning: Columns (2,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   list = pd.read_csv("listFINAL.csv")

# %% [markdown]
# ### Convert Date Fields to Datetime Format

# %%
#converting sold dataset
sold["CloseDate"] = pd.to_datetime(sold["CloseDate"])
sold["PurchaseContractDate"] = pd.to_datetime(sold["PurchaseContractDate"])
sold["ListingContractDate"] = pd.to_datetime(sold["ListingContractDate"])
sold["ContractStatusChangeDate"] = pd.to_datetime(sold["ContractStatusChangeDate"])

# %%
#converting list dataset
list["CloseDate"] = pd.to_datetime(list["CloseDate"])
list["PurchaseContractDate"] = pd.to_datetime(list["PurchaseContractDate"])
list["ListingContractDate"] = pd.to_datetime(list["ListingContractDate"])
list["ContractStatusChangeDate"] = pd.to_datetime(list["ContractStatusChangeDate"])

# %% [markdown]
# ### Remove Unnecessary Columns

# %% [markdown]
# ### Already removed unnecessary columns that had over 90% missing data in Week 2

# %% [markdown]
# ### Analyze Missing Values

# %% [markdown]
# # checked percentage of missing values in each column to double check if any columns needed to be dropped that had high number of missing values and dropped them accordingly if needed

# %%
sold_missing = sold.isnull().mean()*100
sold_missing[sold_missing>0].sort_values(ascending=False)
# Out:
# WaterfrontYN                   99.936771
# BasementYN                     98.051697
# BuyerAgencyCompensation        89.117766
# BuyerAgencyCompensationType    89.115171
# ElementarySchool               86.780416
# MiddleOrJuniorSchool           86.697133
# OriginatingSystemSubName       82.986911
# OriginatingSystemName          82.986911
# HighSchool                     82.708986
# CoListAgentFirstName           77.054471
# CoListAgentLastName            76.993130
# CoListOfficeName               76.319552
# SubdivisionName                62.742771
# AssociationFeeFrequency        58.332075
# MainLevelBedrooms              41.903382
# Flooring                       35.994772
# HighSchoolDistrict             27.541193
# AssociationFee                 22.814116
# AttachedGarageYN               15.330678
# Stories                        15.265326
# MLSAreaMajor                   13.370815
# BuyerAgentAOR                  12.415301
# ListAgentAOR                   10.899928
# Levels                          9.492847
# ViewYN                          8.542524
# PoolPrivateYN                   8.490384
# LotSizeAcres                    7.805245
# LotSizeSquareFeet               7.709458
# LotSizeArea                     7.680439
# NewConstructionYN               7.424927
# BuyerOfficeAOR                  5.826507
# Latitude                        4.429099
# Longitude                       4.429099
# GarageSpaces                    4.307831
# ListAgentEmail                  4.118616
# BuyerOfficeName                 1.590870
# ListAgentFirstName              0.740582
# BuyerAgentFirstName             0.482003
# ContractStatusChangeDate        0.277925
# ParkingTotal                    0.200540
# PropertySubType                 0.194406
# OriginalListPrice               0.186148
# BuyerAgentMlsId                 0.129997
# StreetNumberNumeric             0.121032
# UnparsedAddress                 0.099562
# YearBuilt                       0.088709
# FireplaceYN                     0.079272
# City                            0.072430
# LivingArea                      0.055443
# PurchaseContractDate            0.046950
# BuyerAgentLastName              0.042231
# ListAgentFullName               0.022649
# BathroomsTotalInteger           0.015807
# ListAgentLastName               0.009437
# BedroomsTotal                   0.002831
# PostalCode                      0.000708
# ClosePrice                      0.000472
# ListingContractDate             0.000236
# dtype: float64

# %%
#dropped waterfront and basement columns because over 90% missing data
sold=sold.drop(columns=["WaterfrontYN","BasementYN"])

# %%
list_missing = list.isnull().mean()*100
list_missing[list_missing>0].sort_values(ascending=False)
# Out:
# ElementarySchool               88.083826
# MiddleOrJuniorSchool           88.078077
# BuyerAgencyCompensation        86.644518
# BuyerAgencyCompensationType    86.641137
# HighSchool                     84.367291
# CoListAgentFirstName           77.680674
# CoListAgentLastName            77.605268
# CoListOfficeName               77.588361
# ClosePrice                     75.351881
# BuyerOfficeAOR                 74.906546
# BuyerOfficeName                73.110835
# BuyerAgentFirstName            72.854015
# BuyerAgentMlsId                72.746316
# BuyerAgentLastName             72.727718
# CloseDate                      71.475404
# SubdivisionName                63.229101
# AssociationFeeFrequency        57.169232
# PurchaseContractDate           52.332429
# MainLevelBedrooms              45.766529
# HighSchoolDistrict             30.124352
# AssociationFee                 24.109288
# Stories                        17.585318
# AttachedGarageYN               17.505347
# Latitude                       13.650850
# Longitude                      13.650850
# MLSAreaMajor                   13.572739
# Levels                         10.888725
# LotSizeAcres                    8.210630
# LotSizeSquareFeet               8.087883
# LotSizeArea                     8.056267
# NewConstructionYN               6.871074
# GarageSpaces                    5.571758
# ListAgentEmail                  4.307947
# ContractStatusChangeDate        1.168962
# ListAgentFirstName              0.784662
# PropertySubType                 0.230445
# StreetNumberNumeric             0.178033
# YearBuilt                       0.171946
# UnparsedAddress                 0.143711
# OriginalListPrice               0.142358
# FireplaceYN                     0.105501
# LivingArea                      0.101781
# City                            0.100936
# BedroomsTotal                   0.027390
# ListAgentFullName               0.017583
# StateOrProvince                 0.009806
# BathroomsTotalInteger           0.009637
# ListAgentLastName               0.007101
# PostalCode                      0.003551
# ParkingTotal                    0.003381
# dtype: float64

# %% [markdown]
# ### Ensure Numeric Fields are Proper

# %%
#converting all column names into numeric if needed
numeric_cols = ["ClosePrice","ListPrice","OriginalListPrice",
                "LivingArea","LotSizeAcres","BedroomsTotal",
                "BathroomsTotalInteger","DaysOnMarket"]
for col in numeric_cols:
    if col in list.columns:
        list[col]=pd.to_numeric(list[col],errors="coerce")
    if col in sold.columns:
        sold[col]=pd.to_numeric(sold[col],errors="coerce")

# %% [markdown]
# ### Removing or Flagging Invalid Numeric Values

# %%
#flagging invalid numeric values in list
list["invalid_nums"] = (
    (list["ClosePrice"]<=0) | (list["LivingArea"]<=0) |
    (list["DaysOnMarket"]<0) | (list["BedroomsTotal"]<0) |
    (list["BathroomsTotalInteger"]<0)
)

#no invalid numeric values in list
list["invalid_nums"].sum()
# Out:
# 0

# %%
#flagging invalid numeric values in sold
sold["invalid_nums"] = (
    (sold["ClosePrice"]<=0) | (sold["LivingArea"]<=0) |
    (sold["DaysOnMarket"]<0) | (sold["BedroomsTotal"]<0) |
    (sold["BathroomsTotalInteger"]<0)
)

#no invalid numeric values in sold
sold["invalid_nums"].sum()
# Out:
# 0

# %% [markdown]
# ### Data Consistency Checks

# %% [markdown]
# ### Geographic Data Checks
